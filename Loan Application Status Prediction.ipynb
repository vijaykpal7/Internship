# %%
import pandas as pd
import  numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import svm
from sklearn.metrics import accuracy_score
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Loan%20Application%20Status/loan_prediction.csv')
df
# Out:
#      LP001002    Male   No   0      Graduate No.1  5849     0.1  Unnamed: 8  \
# 0    LP001003    Male  Yes   1      Graduate   No  4583  1508.0       128.0
# 1    LP001005    Male  Yes   0      Graduate  Yes  3000     0.0        66.0
# 2    LP001006    Male  Yes   0  Not Graduate   No  2583  2358.0       120.0
# 3    LP001008    Male   No   0      Graduate   No  6000     0.0       141.0
# 4    LP001011    Male  Yes   2      Graduate  Yes  5417  4196.0       267.0
# ..        ...     ...  ...  ..           ...  ...   ...     ...         ...
# 608  LP002978  Female   No   0      Graduate   No  2900     0.0        71.0
# 609  LP002979    Male  Yes  3+      Graduate   No  4106     0.0        40.0
# 610  LP002983    Male  Yes   1      Graduate   No  8072   240.0       253.0
# 611  LP002984    Male  Yes   2      Graduate   No  7583     0.0       187.0
# 612  LP002990  Female   No   0      Graduate  Yes  4583     0.0       133.0
#
#        360    1      Urban  Y
# 0    360.0  1.0      Rural  N
# 1    360.0  1.0      Urban  Y
# 2    360.0  1.0      Urban  Y
# 3    360.0  1.0      Urban  Y
# 4    360.0  1.0      Urban  Y
# ..     ...  ...        ... ..
# 608  360.0  1.0      Rural  Y
# 609  180.0  1.0      Rural  Y
# 610  360.0  1.0      Urban  Y
# 611  360.0  1.0      Urban  Y
# 612  360.0  0.0  Semiurban  N
#
# [613 rows x 13 columns]

# %%
df.head(15)
# Out:
#     LP001002  Male   No   0      Graduate No.1   5849      0.1  Unnamed: 8  \
# 0   LP001003  Male  Yes   1      Graduate   No   4583   1508.0       128.0
# 1   LP001005  Male  Yes   0      Graduate  Yes   3000      0.0        66.0
# 2   LP001006  Male  Yes   0  Not Graduate   No   2583   2358.0       120.0
# 3   LP001008  Male   No   0      Graduate   No   6000      0.0       141.0
# 4   LP001011  Male  Yes   2      Graduate  Yes   5417   4196.0       267.0
# 5   LP001013  Male  Yes   0  Not Graduate   No   2333   1516.0        95.0
# 6   LP001014  Male  Yes  3+      Graduate   No   3036   2504.0       158.0
# 7   LP001018  Male  Yes   2      Graduate   No   4006   1526.0       168.0
# 8   LP001020  Male  Yes   1      Graduate   No  12841  10968.0       349.0
# 9   LP001024  Male  Yes   2      Graduate   No   3200    700.0        70.0
# 10  LP001027  Male  Yes   2      Graduate  NaN   2500   1840.0       109.0
# 11  LP001028  Male  Yes   2      Graduate   No   3073   8106.0       200.0
# 12  LP001029  Male   No   0      Graduate   No   1853   2840.0       114.0
# 13  LP001030  Male  Yes   2      Graduate   No   1299   1086.0        17.0
# 14  LP001032  Male   No   0      Graduate   No   4950      0.0       125.0
#
#       360    1      Urban  Y
# 0   360.0  1.0      Rural  N
# 1   360.0  1.0      Urban  Y
# 2   360.0  1.0      Urban  Y
# 3   360.0  1.0      Urban  Y
# 4   360.0  1.0      Urban  Y
# 5   360.0  1.0      Urban  Y
# 6   360.0  0.0  Semiurban  N
# 7   360.0  1.0      Urban  Y
# 8   360.0  1.0  Semiurban  N
# 9   360.0  1.0      Urban  Y
# 10  360.0  1.0      Urban  Y
# 11  360.0  1.0      Urban  Y
# 12  360.0  1.0      Rural  N
# 13  120.0  1.0      Urban  Y
# 14  360.0  1.0      Urban  Y

# %%
df.tail(10)
# Out:
#      LP001002    Male   No   0      Graduate No.1   5849     0.1  Unnamed: 8  \
# 603  LP002959  Female  Yes   1      Graduate   No  12000     0.0       496.0
# 604  LP002960    Male  Yes   0  Not Graduate   No   2400  3800.0         NaN
# 605  LP002961    Male  Yes   1      Graduate   No   3400  2500.0       173.0
# 606  LP002964    Male  Yes   2  Not Graduate   No   3987  1411.0       157.0
# 607  LP002974    Male  Yes   0      Graduate   No   3232  1950.0       108.0
# 608  LP002978  Female   No   0      Graduate   No   2900     0.0        71.0
# 609  LP002979    Male  Yes  3+      Graduate   No   4106     0.0        40.0
# 610  LP002983    Male  Yes   1      Graduate   No   8072   240.0       253.0
# 611  LP002984    Male  Yes   2      Graduate   No   7583     0.0       187.0
# 612  LP002990  Female   No   0      Graduate  Yes   4583     0.0       133.0
#
#        360    1      Urban  Y
# 603  360.0  1.0  Semiurban  Y
# 604  180.0  1.0      Urban  N
# 605  360.0  1.0  Semiurban  Y
# 606  360.0  1.0      Rural  Y
# 607  360.0  1.0      Rural  Y
# 608  360.0  1.0      Rural  Y
# 609  180.0  1.0      Rural  Y
# 610  360.0  1.0      Urban  Y
# 611  360.0  1.0      Urban  Y
# 612  360.0  0.0  Semiurban  N

# %%
df.shape
# Out:
# (613, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 613 entries, 0 to 612
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LP001002    613 non-null    object
#  1   Male        600 non-null    object
#  2   No          610 non-null    object
#  3   0           598 non-null    object
#  4   Graduate    613 non-null    object
#  5   No.1        581 non-null    object
#  6   5849        613 non-null    int64
#  7   0.1         613 non-null    float64
#  8   Unnamed: 8  592 non-null    float64
#  9   360         599 non-null    float64
#  10  1           563 non-null    float64
#  11  Urban       613 non-null    object
#  12  Y           613 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.4+ KB

# %%
df.describe()
# Out:
#                5849           0.1  Unnamed: 8         360           1
# count    613.000000    613.000000  592.000000  599.000000  563.000000
# mean    5402.732463   1623.890571  146.412162  341.969950    0.841918
# std     6114.004114   2927.903583   85.587325   65.170672    0.365142
# min      150.000000      0.000000    9.000000   12.000000    0.000000
# 25%     2876.000000      0.000000  100.000000  360.000000    1.000000
# 50%     3812.000000   1210.000000  128.000000  360.000000    1.000000
# 75%     5780.000000   2302.000000  168.000000  360.000000    1.000000
# max    81000.000000  41667.000000  700.000000  480.000000    1.000000

# %%
df.isnull().sum()
# Out:
# LP001002       0
# Male          13
# No             3
# 0             15
# Graduate       0
# No.1          32
# 5849           0
# 0.1            0
# Unnamed: 8    21
# 360           14
# 1             50
# Urban          0
# Y              0
# dtype: int64

# %%
df.dropna()
# Out:
#      LP001002    Male   No   0      Graduate No.1  5849     0.1  Unnamed: 8  \
# 0    LP001003    Male  Yes   1      Graduate   No  4583  1508.0       128.0
# 1    LP001005    Male  Yes   0      Graduate  Yes  3000     0.0        66.0
# 2    LP001006    Male  Yes   0  Not Graduate   No  2583  2358.0       120.0
# 3    LP001008    Male   No   0      Graduate   No  6000     0.0       141.0
# 4    LP001011    Male  Yes   2      Graduate  Yes  5417  4196.0       267.0
# ..        ...     ...  ...  ..           ...  ...   ...     ...         ...
# 608  LP002978  Female   No   0      Graduate   No  2900     0.0        71.0
# 609  LP002979    Male  Yes  3+      Graduate   No  4106     0.0        40.0
# 610  LP002983    Male  Yes   1      Graduate   No  8072   240.0       253.0
# 611  LP002984    Male  Yes   2      Graduate   No  7583     0.0       187.0
# 612  LP002990  Female   No   0      Graduate  Yes  4583     0.0       133.0
#
#        360    1      Urban  Y
# 0    360.0  1.0      Rural  N
# 1    360.0  1.0      Urban  Y
# 2    360.0  1.0      Urban  Y
# 3    360.0  1.0      Urban  Y
# 4    360.0  1.0      Urban  Y
# ..     ...  ...        ... ..
# 608  360.0  1.0      Rural  Y
# 609  180.0  1.0      Rural  Y
# 610  360.0  1.0      Urban  Y
# 611  360.0  1.0      Urban  Y
# 612  360.0  0.0  Semiurban  N
#
# [480 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# LP001002       0
# Male          13
# No             3
# 0             15
# Graduate       0
# No.1          32
# 5849           0
# 0.1            0
# Unnamed: 8    21
# 360           14
# 1             50
# Urban          0
# Y              0
# dtype: int64

# %%
df['Graduate'].value_counts()
# Out:
# Graduate        479
# Not Graduate    134
# Name: Graduate, dtype: int64

# %%
df.replace({"No": {'N': 0, 'Y': 1}}, inplace=True)

# %%
df.head(15)
# Out:
#     LP001002  Male   No   0      Graduate No.1   5849      0.1  Unnamed: 8  \
# 0   LP001003  Male  Yes   1      Graduate   No   4583   1508.0       128.0
# 1   LP001005  Male  Yes   0      Graduate  Yes   3000      0.0        66.0
# 2   LP001006  Male  Yes   0  Not Graduate   No   2583   2358.0       120.0
# 3   LP001008  Male   No   0      Graduate   No   6000      0.0       141.0
# 4   LP001011  Male  Yes   2      Graduate  Yes   5417   4196.0       267.0
# 5   LP001013  Male  Yes   0  Not Graduate   No   2333   1516.0        95.0
# 6   LP001014  Male  Yes  3+      Graduate   No   3036   2504.0       158.0
# 7   LP001018  Male  Yes   2      Graduate   No   4006   1526.0       168.0
# 8   LP001020  Male  Yes   1      Graduate   No  12841  10968.0       349.0
# 9   LP001024  Male  Yes   2      Graduate   No   3200    700.0        70.0
# 10  LP001027  Male  Yes   2      Graduate  NaN   2500   1840.0       109.0
# 11  LP001028  Male  Yes   2      Graduate   No   3073   8106.0       200.0
# 12  LP001029  Male   No   0      Graduate   No   1853   2840.0       114.0
# 13  LP001030  Male  Yes   2      Graduate   No   1299   1086.0        17.0
# 14  LP001032  Male   No   0      Graduate   No   4950      0.0       125.0
#
#       360    1      Urban  Y
# 0   360.0  1.0      Rural  N
# 1   360.0  1.0      Urban  Y
# 2   360.0  1.0      Urban  Y
# 3   360.0  1.0      Urban  Y
# 4   360.0  1.0      Urban  Y
# 5   360.0  1.0      Urban  Y
# 6   360.0  0.0  Semiurban  N
# 7   360.0  1.0      Urban  Y
# 8   360.0  1.0  Semiurban  N
# 9   360.0  1.0      Urban  Y
# 10  360.0  1.0      Urban  Y
# 11  360.0  1.0      Urban  Y
# 12  360.0  1.0      Rural  N
# 13  120.0  1.0      Urban  Y
# 14  360.0  1.0      Urban  Y
