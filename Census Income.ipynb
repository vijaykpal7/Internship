# %%
import pandas as pd
import  numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import svm
from sklearn.metrics import accuracy_score
import warnings
warnings.filterwarnings('ignore')

# %%
url=("https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Census%20Income/Census%20Income.csv")
df = pd.read_csv(url)
df
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
df.head(15)
# Out:
#     Age          Workclass  Fnlwgt      Education  Education_num  \
# 0    50   Self-emp-not-inc   83311      Bachelors             13
# 1    38            Private  215646        HS-grad              9
# 2    53            Private  234721           11th              7
# 3    28            Private  338409      Bachelors             13
# 4    37            Private  284582        Masters             14
# 5    49            Private  160187            9th              5
# 6    52   Self-emp-not-inc  209642        HS-grad              9
# 7    31            Private   45781        Masters             14
# 8    42            Private  159449      Bachelors             13
# 9    37            Private  280464   Some-college             10
# 10   30          State-gov  141297      Bachelors             13
# 11   23            Private  122272      Bachelors             13
# 12   32            Private  205019     Assoc-acdm             12
# ...

# %%
df.tail(15)
# Out:
#        Age          Workclass  Fnlwgt      Education  Education_num  \
# 32545   37            Private  198216     Assoc-acdm             12
# 32546   43            Private  260761        HS-grad              9
# 32547   65   Self-emp-not-inc   99359    Prof-school             15
# 32548   43          State-gov  255835   Some-college             10
# 32549   43   Self-emp-not-inc   27242   Some-college             10
# 32550   32            Private   34066           10th              6
# 32551   43            Private   84661      Assoc-voc             11
# 32552   32            Private  116138        Masters             14
# 32553   53            Private  321865        Masters             14
# 32554   22            Private  310152   Some-college             10
# 32555   27            Private  257302     Assoc-acdm             12
# 32556   40            Private  154374        HS-grad              9
# 32557   58            Private  151910        HS-grad              9
# ...

# %%
df.shape
# Out:
# (32560, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  object
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  object
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  object
#  6   Occupation      32560 non-null  object
#  7   Relationship    32560 non-null  object
#  8   Race            32560 non-null  object
#  9   Sex             32560 non-null  object
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  object
#  14  Income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['Age',
#  'Workclass',
#  'Fnlwgt',
#  'Education',
#  'Education_num',
#  'Marital_status',
#  'Occupation',
#  'Relationship',
#  'Race',
#  'Sex',
#  'Capital_gain',
#  'Capital_loss',
#  'Hours_per_week',
#  'Native_country',
#  'Income']

# %%
df.dtypes
# Out:
# Age                int64
# Workclass         object
# Fnlwgt             int64
# Education         object
# Education_num      int64
# Marital_status    object
# Occupation        object
# Relationship      object
# Race              object
# Sex               object
# Capital_gain       int64
# Capital_loss       int64
# Hours_per_week     int64
# Native_country    object
# Income            object
# dtype: object

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df['Age'].unique()
# Out:
# array([50, 38, 53, 28, 37, 49, 52, 31, 42, 30, 23, 32, 40, 34, 25, 43, 54,
#        35, 59, 56, 19, 39, 20, 45, 22, 48, 21, 24, 57, 44, 41, 29, 18, 47,
#        46, 36, 79, 27, 67, 33, 76, 17, 55, 61, 70, 64, 71, 68, 66, 51, 58,
#        26, 60, 90, 75, 65, 77, 62, 63, 80, 72, 74, 69, 73, 81, 78, 88, 82,
#        83, 84, 85, 86, 87], dtype=int64)

# %%
df['Age'].nunique()
# Out:
# 73

# %%
for i in df.columns:
    print (df[i].value_counts())
    print("\n")
# Out:
# 36    898
# 31    888
# 34    886
# 23    877
# 35    876
#      ...
# 83      6
# 88      3
# 85      3
# 86      1
# 87      1
# Name: Age, Length: 73, dtype: int64
#
#
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: Workclass, dtype: int64
#
#
# 164190    13
# 203488    13
# 123011    13
# 148995    12
# 126675    12
#           ..
# 325573     1
# 140176     1
# 318264     1
# 329205     1
# 257302     1
# Name: Fnlwgt, Length: 21647, dtype: int64
#
#
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5354
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
# ...

# %%
df.shape[0]
# Out:
# 32560

# %%
df.loc[df["Age"]==" "]
# Out:
# Empty DataFrame
# Columns: [Age, Workclass, Fnlwgt, Education, Education_num, Marital_status, Occupation, Relationship, Race, Sex, Capital_gain, Capital_loss, Hours_per_week, Native_country, Income]
# Index: []

# %%
print("Age:", df["Age"].sort_values(ascending=True))
# Out:
# Age: 15541    17
# 26089    17
# 22495    17
# 22856    17
# 12980    17
#          ..
# 11511    90
# 12450    90
# 6623     90
# 18831    90
# 8805     90
# Name: Age, Length: 32560, dtype: int64

# %%
df.iloc[488,:]
# Out:
# Age                                38
# Workclass                     Private
# Fnlwgt                          91039
# Education                   Bachelors
# Education_num                      13
# Marital_status     Married-civ-spouse
# Occupation                      Sales
# Relationship                  Husband
# Race                            White
# Sex                              Male
# Capital_gain                    15024
# Capital_loss                        0
# Hours_per_week                     60
# Native_country          United-States
# Income                           >50K
# Name: 488, dtype: object

# %%
if len(df) > 488:
    print(df.iloc[488, :])
else:
    print("Index 488 is out of bounds for the DataFrame.")
# Out:
# Age                                38
# Workclass                     Private
# Fnlwgt                          91039
# Education                   Bachelors
# Education_num                      13
# Marital_status     Married-civ-spouse
# Occupation                      Sales
# Relationship                  Husband
# Race                            White
# Sex                              Male
# Capital_gain                    15024
# Capital_loss                        0
# Hours_per_week                     60
# Native_country          United-States
# Income                           >50K
# Name: 488, dtype: object

# %%
categorical_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]=="object":
        categorical_col.append(i)
print("Categorical columns:",categorical_col)
print("\n")

numerical_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]!="object":
        numerical_col.append(i)
print("Numerical Columns:",numerical_col)
# Out:
# Categorical columns: ['Workclass', 'Education', 'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex', 'Native_country', 'Income']
#
#
# Numerical Columns: ['Age', 'Fnlwgt', 'Education_num', 'Capital_gain', 'Capital_loss', 'Hours_per_week']

# %%
df.nunique().to_frame("no. of unique values")
# Out:
#                 no. of unique values
# Age                               73
# Workclass                          9
# Fnlwgt                         21647
# Education                         16
# Education_num                     16
# Marital_status                     7
# Occupation                        15
# Relationship                       6
# Race                               5
# Sex                                2
# Capital_gain                     119
# Capital_loss                      92
# Hours_per_week                    94
# Native_country                    42
# Income                             2

# %%
df.head()
# Out:
#    Age          Workclass  Fnlwgt   Education  Education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital_status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# 0             0             0              13   United-States   <=50K
# ...

# %%
df.describe()
# Out:
#                 Age        Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# count  32560.000000  3.256000e+04   32560.000000  32560.000000  32560.000000
# mean      38.581634  1.897818e+05      10.080590   1077.615172     87.306511
# std       13.640642  1.055498e+05       2.572709   7385.402999    402.966116
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        Hours_per_week
# count    32560.000000
# mean        40.437469
# std         12.347618
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# ### DATA Visualization Univariate Analysis

# %%
print(df['Age'].value_counts())
ax=sns.countplot(x='Age',data=df)
plt.show()
# Out:
# 36    898
# 31    888
# 34    886
# 23    877
# 35    876
#      ...
# 83      6
# 88      3
# 85      3
# 86      1
# 87      1
# Name: Age, Length: 73, dtype: int64

# %%
print(df['Workclass'].value_counts())
ax=sns.countplot(x='Workclass',data=df)
plt.show()
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: Workclass, dtype: int64

# %%
print(df['Fnlwgt'].value_counts())
ax=sns.countplot(x='Fnlwgt',data=df)
plt.show()
# Out:
# 164190    13
# 203488    13
# 123011    13
# 148995    12
# 126675    12
#           ..
# 325573     1
# 140176     1
# 318264     1
# 329205     1
# 257302     1
# Name: Fnlwgt, Length: 21647, dtype: int64

# %%
print(df['Education'].value_counts())
ax=sns.countplot(x='Education',data=df)
plt.show()
# Out:
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5354
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: Education, dtype: int64

# %%
print(df['Education_num'].value_counts())
ax=sns.countplot(x='Education_num',data=df)
plt.show()
# Out:
# 9     10501
# 10     7291
# 13     5354
# 14     1723
# 11     1382
# 7      1175
# 12     1067
# 6       933
# 4       646
# 15      576
# 5       514
# 8       433
# 16      413
# 3       333
# 2       168
# 1        51
# Name: Education_num, dtype: int64

# %%
print(df['Marital_status'].value_counts())
ax=sns.countplot(x='Marital_status',data=df)
plt.show()
# Out:
#  Married-civ-spouse       14976
#  Never-married            10682
#  Divorced                  4443
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
# Name: Marital_status, dtype: int64

# %%
print(df['Occupation'].value_counts())
ax=sns.countplot(x='Occupation',data=df)
plt.show()
# Out:
#  Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3769
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  ?                    1843
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name: Occupation, dtype: int64

# %%
print(df['Relationship'].value_counts())
ax=sns.countplot(x='Relationship',data=df)
plt.show()
# Out:
#  Husband           13193
#  Not-in-family      8304
#  Own-child          5068
#  Unmarried          3446
#  Wife               1568
#  Other-relative      981
# Name: Relationship, dtype: int64

# %%
print(df['Race'].value_counts())
ax=sns.countplot(x='Race',data=df)
plt.show()
# Out:
#  White                 27815
#  Black                  3124
#  Asian-Pac-Islander     1039
#  Amer-Indian-Eskimo      311
#  Other                   271
# Name: Race, dtype: int64

# %%
print(df['Sex'].value_counts())
ax=sns.countplot(x='Sex',data=df)
plt.show()
# Out:
#  Male      21789
#  Female    10771
# Name: Sex, dtype: int64

# %%
print(df['Capital_gain'].value_counts())
ax=sns.countplot(x='Capital_gain',data=df)
plt.show()
# Out:
# 0        29849
# 15024      347
# 7688       284
# 7298       246
# 99999      159
#          ...
# 1111         1
# 2538         1
# 22040        1
# 4931         1
# 5060         1
# Name: Capital_gain, Length: 119, dtype: int64

# %%
print(df['Capital_loss'].value_counts())
ax=sns.countplot(x='Capital_loss',data=df)
plt.show()
# Out:
# 0       31041
# 1902      202
# 1977      168
# 1887      159
# 1848       51
#         ...
# 2080        1
# 1539        1
# 1844        1
# 2489        1
# 1411        1
# Name: Capital_loss, Length: 92, dtype: int64

# %%
print(df['Hours_per_week'].value_counts())
ax=sns.countplot(x='Hours_per_week',data=df)
plt.show()
# Out:
# 40    15216
# 50     2819
# 45     1824
# 60     1475
# 35     1297
#       ...
# 82        1
# 94        1
# 92        1
# 74        1
# 87        1
# Name: Hours_per_week, Length: 94, dtype: int64

# %%
print(df['Native_country'].value_counts())
ax=sns.countplot(x='Native_country',data=df)
plt.show()
# Out:
#  United-States                 29169
#  Mexico                          643
#  ?                               583
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
# ...

# %%
print(df['Income'].value_counts())
ax=sns.countplot(x='Income',data=df)
plt.show()
# Out:
#  <=50K    24719
#  >50K      7841
# Name: Income, dtype: int64

# %%
plt.figure(figsize=(10,6),facecolor='white')
plotnumber=1
for col in numerical_col:
    if plotnumber <=4:
        ax=plt.subplot(2,2,plotnumber)
        sns.distplot(df[col],color="m")
        plt.xlabel(col,fontsize=12)
        plt.yticks(rotation=0,fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# ### BIVARIATE Analysis

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
plt.title("comparison between Age and Workclass")
sns.stripplot(x="Age",y="Workclass",data=df)
plt.show()

# %%
plt.title("comparison between Fnlwgt and Education")
sns.stripplot(x="Fnlwgt",y="Education",data=df)
plt.show()

# %%
plt.title("comparison between Education and Education_num")
sns.stripplot(x="Education_num",y="Education",data=df)
plt.show()

# %%
plt.title("comparison between Marital_status and Occupation")
sns.stripplot(x="Marital_status",y="Occupation",data=df)
plt.show()

# %%
plt.title("comparison between Relationship and Race")
sns.stripplot(x="Relationship",y="Race",data=df)
plt.show()

# %%
plt.title("comparison between Sex and Capital_gain")
sns.stripplot(x="Sex",y="Capital_gain",data=df)
plt.show()

# %%
plt.title("comparison between Capital_loss and Capital_gain")
sns.stripplot(x="Capital_loss",y="Capital_gain",data=df)
plt.show()

# %%
plt.title("comparison between Hours_per_week and Native_country")
sns.stripplot(x="Hours_per_week",y="Native_country",data=df)
plt.show()

# %%
plt.title("comparison between Income and Native_country")
sns.stripplot(x="Income",y="Native_country",data=df)
plt.show()
